# %%
from functions import *

from IPython.core.display import HTML
import matplotlib.pyplot as plt
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")

plt.rcParams["figure.figsize"] = (20, 10)

# %%
df = read_data()
df = enrich_df(df)
df = filter_df(df)
# Out:
# Reading the data...
# Enrich the data...
# Filter the data...

# %%
df.user_id.unique()
# Out:
# array([ 861100071, 1853210804, 3330315587])

# %%
plot_scatter(df, 1853210804)

# %%
sub_df = df.query("user_id == {}".format("861100071"))
sub_df['label'] = do_clustering(sub_df)
plot_home_work(sub_df)
# Out:
# Clustering the data...
# /tmp/ipykernel_4095000/3788749914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['label'] = do_clustering(sub_df)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Clustering done.

# %%
sub_df = df.query("user_id == {}".format("1853210804"))
sub_df['label'] = do_clustering(sub_df)
plot_home_work(sub_df)
# Out:
# Clustering the data...
# /tmp/ipykernel_4095000/3000002137.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['label'] = do_clustering(sub_df)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Clustering done.

# %%
sub_df = df.query("user_id == {}".format("3330315587"))
sub_df['label'] = do_clustering(sub_df)
plot_home_work(sub_df)
# Out:
# Clustering the data...
# /tmp/ipykernel_4095000/2502929105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['label'] = do_clustering(sub_df)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Clustering done.
